# %%
import pandas as pd

# %%
daily_df = pd.read_json('2023-12-02-daily.json', orient='index')
unique_df = pd.read_json('2023-12-02-unique.json', orient='index')

# %%
daily_df.head()
# Out:
#        rank                 name  price_format  current_player  peak_player  \
# 65704     1     Counter-Strike 2          0.00          772965      1131833
# 65705     2               Dota 2          0.00          442558       641916
# 65706     3      Baldur's Gate 3         59.99          161302       164967
# 65707     4        Apex Legends™          0.00          109764       403722
# 65708     5  PUBG: BATTLEGROUNDS          0.00          109153       396913
#
#        hour       date  num_curators  num_pos_reviews  num_neg_reviews
# 65704    20 2023-10-19         17564          6766697           919546
# 65705    20 2023-10-19          5123          1705517           371183
# 65706    20 2023-10-19           558           355348            14910
# 65707    20 2023-10-19           935           584377           147996
# 65708    20 2023-10-19          2027          1283376           949330

# %%
name_genre_df = unique_df[['name', 'genre']]
name_genre_df = name_genre_df.set_index('name')

# %%
name_genre_dict = name_genre_df.to_dict()
name_genre_dict
# Out:
# {'genre': {'Counter-Strike 2': ['Action', 'Free to Play'],
#   'Warframe': ['Action', 'RPG', 'Free to Play'],
#   'Wallpaper Engine': ['Casual',
#    'Indie',
#    'Animation & Modeling',
#    'Design & Illustration',
#    'Photo Editing',
#    'Utilities'],
#   'Stardew Valley': ['Indie', 'RPG', 'Simulation'],
#   'VRChat': ['Adventure',
#    'Casual',
#    'Massively Multiplayer',
#    'Simulation',
#    'Sports',
#    'Free to Play',
#    'Early Access'],
#   'The Binding of Isaac: Rebirth': ['Action'],
#   'Terraria': ['Action', 'Adventure', 'Indie', 'RPG'],
#   'Age of Empires II: Definitive Edition': ['Strategy'],
#   'Dota 2': ['Action', 'Strategy', 'Free to Play'],
#   'Valheim': ['Action', 'Adventure', 'Indie', 'RPG', 'Early Access'],
#   'ARK: Survival Evolved': ['Action',
#    'Adventure',
#    'Indie',
#    'Massively Multiplayer',
#    'RPG'],
#   'MIR4': ['Action',
#    'Adventure',
#    'Free to Play',
#    'Massively Multiplayer',
#    'RPG'],
# ...
